# %% [markdown]
# <a href="https://colab.research.google.com/github/SureNotEDT/weather/blob/master/%D0%9A%D0%BE%D0%BF%D0%B8%D1%8F_%D0%B1%D0%BB%D0%BE%D0%BA%D0%BD%D0%BE%D1%82%D0%B0_%22Yolov8_project%22.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !mv settings.yaml /root/.config/Ultralytics/

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import torch
import torchvision
print(torch.__version__)  # Версия PyTorch
print(torchvision.__version__)
# Out:
# 2.3.0+cu121
# 0.18.0+cu121

# %%
from ultralytics import YOLO
import torch

# %%
# !yolo train model=yolov8n.pt data=drive/MyDrive/dataset_yolo/data.yaml epochs=100 imgsz=640
# Out:
# Ultralytics YOLOv8.2.22 🚀 Python-3.10.12 torch-2.3.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
# !ls content/runs/detect/train/weights
# Out:
# ls: cannot access 'content/runs/detect/train/weights': No such file or directory
